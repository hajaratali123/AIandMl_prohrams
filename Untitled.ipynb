# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# loading the data from the csv file to apandas dataframe
movies_data = pd.read_csv('movies.csv')

# %%
# printing the first 5 rows of the dataframe
movies_data.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
# selecting the relevant features for recommendation

selected_features = ['genres','keywords','tagline','cast','director']
print(selected_features)
# Out:
# ['genres', 'keywords', 'tagline', 'cast', 'director']

# %%
# replacing the null valuess with null string

for feature in selected_features:
  movies_data[feature] = movies_data[feature].fillna('')

# %%
# combining all the 5 selected features

combined_features = movies_data['genres']+' '+movies_data['keywords']+' '+movies_data['tagline']+' '+movies_data['cast']+' '+movies_data['director']

# %%
print(combined_features)
# Out:
# 0       Action Adventure Fantasy Science Fiction cultu...
# 1       Adventure Fantasy Action ocean drug abuse exot...
# 2       Action Adventure Crime spy based on novel secr...
# 3       Action Crime Drama Thriller dc comics crime fi...
# 4       Action Adventure Science Fiction based on nove...
#                               ...
# 4798    Action Crime Thriller united states\u2013mexic...
# 4799    Comedy Romance  A newlywed couple's honeymoon ...
# 4800    Comedy Drama Romance TV Movie date love at fir...
# 4801      A New Yorker in Shanghai Daniel Henney Eliza...
# 4802    Documentary obsession camcorder crush dream gi...
# Length: 4803, dtype: object

# %%
# converting the text data to feature vectors numaricale data

vectorizer = TfidfVectorizer()

# %%
feature_vectors = vectorizer.fit_transform(combined_features)

# %%
print(feature_vectors)
# Out:
#   (0, 2432)	0.17272411194153
#   (0, 7755)	0.1128035714854756
#   (0, 13024)	0.1942362060108871
#   (0, 10229)	0.16058685400095302
#   (0, 8756)	0.22709015857011816
#   (0, 14608)	0.15150672398763912
#   (0, 16668)	0.19843263965100372
#   (0, 14064)	0.20596090415084142
#   (0, 13319)	0.2177470539412484
#   (0, 17290)	0.20197912553916567
#   (0, 17007)	0.23643326319898797
#   (0, 13349)	0.15021264094167086
#   (0, 11503)	0.27211310056983656
#   (0, 11192)	0.09049319826481456
#   (0, 16998)	0.1282126322850579
#   (0, 15261)	0.07095833561276566
#   (0, 4945)	0.24025852494110758
#   (0, 14271)	0.21392179219912877
#   (0, 3225)	0.24960162956997736
#   (0, 16587)	0.12549432354918996
#   (0, 14378)	0.33962752210959823
#   (0, 5836)	0.1646750903586285
#   (0, 3065)	0.22208377802661425
#   (0, 3678)	0.21392179219912877
#   (0, 5437)	0.1036413987316636
#   :	:
#   (4801, 17266)	0.2886098184932947
#   (4801, 4835)	0.24713765026963996
#   (4801, 403)	0.17727585190343226
# ...

# %%
# getting the similarity scores using cosine similarity

similarity = cosine_similarity(feature_vectors)

# %%
print(similarity)
# Out:
# [[1.         0.07219487 0.037733   ... 0.         0.         0.        ]
#  [0.07219487 1.         0.03281499 ... 0.03575545 0.         0.        ]
#  [0.037733   0.03281499 1.         ... 0.         0.05389661 0.        ]
#  ...
#  [0.         0.03575545 0.         ... 1.         0.         0.02651502]
#  [0.         0.         0.05389661 ... 0.         1.         0.        ]
#  [0.         0.         0.         ... 0.02651502 0.         1.        ]]

# %%
print(similarity.shape)
# Out:
# (4803, 4803)

# %%
# getting the movie name from the user

movie_name = input(' Enter your favourite movie name : ')

# %%
# creating a list with all the movie names given in the dataset

list_of_all_titles = movies_data['title'].tolist()
print(list_of_all_titles)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
# finding the close match for the movie name given by the user

find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
print(find_close_match)
# Out:
# ['Iron Man', 'Iron Man 3', 'Iron Man 2']

# %%
close_match = find_close_match[0]
print(close_match)
# Out:
# Iron Man

# %%
# finding the index of the movie with title

index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 68

# %%
# getting a list of similar movies

similarity_score = list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, 0.033570748780675445), (1, 0.0546448279236134), (2, 0.013735500604224323), (3, 0.006468756104392058), (4, 0.03268943310073386), (5, 0.013907256685755473), (6, 0.07692837576335507), (7, 0.23944423963486405), (8, 0.007882387851851008), (9, 0.07599206098164225), (10, 0.07536074882460438), (11, 0.01192606921174529), (12, 0.013707618139948929), (13, 0.012376074925089967), (14, 0.09657127116284188), (15, 0.007286271383816743), (16, 0.22704403782296803), (17, 0.013112928084103857), (18, 0.04140526820609594), (19, 0.07883282546834255), (20, 0.07981173664799915), (21, 0.011266873271064948), (22, 0.006892575895462364), (23, 0.006599097891242659), (24, 0.012665208122549737), (25, 0.0), (26, 0.21566241096831154), (27, 0.030581282093826635), (28, 0.061074402219665376), (29, 0.014046184258938898), (30, 0.0807734659476981), (31, 0.31467052449477506), (32, 0.02878209913426701), (33, 0.13089810941050173), (34, 0.0), (35, 0.035350090674865595), (36, 0.03185325269937555), (37, 0.008024326882532318
# ...

# %%
len(similarity_score)
# Out:
# 4803

# %%
# sorting the movies based on their similarity score

sorted_similar_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True)
print(sorted_similar_movies)
# Out:
# [(68, 1.0000000000000002), (79, 0.40890433998005965), (31, 0.31467052449477506), (7, 0.23944423963486405), (16, 0.22704403782296803), (26, 0.21566241096831154), (85, 0.20615862984665329), (182, 0.19573956139611606), (511, 0.16702973947860686), (3623, 0.1609246088135586), (64, 0.15299924139445145), (203, 0.14818667948665118), (174, 0.1471993120942043), (4401, 0.14505971470107848), (101, 0.14401677581826294), (46, 0.14216268867232237), (169, 0.1380947013224906), (1740, 0.13624382641690763), (94, 0.1361681957902901), (788, 0.1330589507422922), (126, 0.13263982780511066), (131, 0.13137698586006535), (33, 0.13089810941050173), (2487, 0.12309731939910507), (783, 0.12162995562040377), (138, 0.11846458075866884), (2442, 0.11725512335483321), (661, 0.11719294096248463), (607, 0.11387063493435637), (38, 0.1126182690487113), (2651, 0.1121878787373205), (353, 0.1116846512704428), (122, 0.10850296033661253), (1553, 0.1079782217151326), (1451, 0.107849394974707), (242, 0.10630339022327012), (618, 
# ...

# %%
# print the name of similar movies based on the index

print('Movies suggested for you : \n')

i = 1

for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index==index]['title'].values[0]
  if (i<=10):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Movies suggested for you :
#
# 1 . Iron Man
# 2 . Iron Man 2
# 3 . Iron Man 3
# 4 . Avengers: Age of Ultron
# 5 . The Avengers
# 6 . Captain America: Civil War
# 7 . Captain America: The Winter Soldier
# 8 . Ant-Man
# 9 . X-Men
# 10 . Made

# %%
movie_name = input(' Enter your favourite movie name : ')

list_of_all_titles = movies_data['title'].tolist()

find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)

close_match = find_close_match[0]

index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]

similarity_score = list(enumerate(similarity[index_of_the_movie]))

sorted_similar_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True) 

print('Movies suggested for you : \n')

i = 1

for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index==index]['title'].values[0]
  if (i<30):
    print(i, '.',title_from_index)
    i+=1
# Out:
#  Enter your favourite movie name :  iron man
# Movies suggested for you :
#
# 1 . Iron Man
# 2 . Iron Man 2
# 3 . Iron Man 3
# 4 . Avengers: Age of Ultron
# 5 . The Avengers
# 6 . Captain America: Civil War
# 7 . Captain America: The Winter Soldier
# 8 . Ant-Man
# 9 . X-Men
# 10 . Made
# 11 . X-Men: Apocalypse
# 12 . X2
# 13 . The Incredible Hulk
# 14 . The Helix... Loaded
# 15 . X-Men: First Class
# 16 . X-Men: Days of Future Past
# 17 . Captain America: The First Avenger
# 18 . Kick-Ass 2
# 19 . Guardians of the Galaxy
# 20 . Deadpool
# 21 . Thor: The Dark World
# 22 . G-Force
# 23 . X-Men: The Last Stand
# 24 . Duets
# 25 . Mortdecai
# 26 . The Last Airbender
# 27 . Southland Tales
# 28 . Zathura: A Space Adventure
# 29 . Sky Captain and the World of Tomorrow

# %% [markdown]
# import difflib
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
#
# # Assuming you have loaded your movie dataset into the 'movies_data' DataFrame
#
# # User input for favorite director
# director_name = input('Enter your favorite director name: ')
#
# # Filter movies by director name
# movies_by_director = movies_data[movies_data['director'].str.contains(director_name, case=False, na=False)]
# print(movies_by_director)
#
# if len(movies_by_director) == 0:
#     print('No movies found for the selected director.')
# else:
#     # Get list of all titles by the selected director
#     # list_of_all_titles = movies_data['title'].tolist()
#     list_of_all_titles = movies_by_director['title'].tolist()
#     print(list_of_all_titles)
#
#     # User input for favorite movie
#     movie_name = input('Enter your favorite movie name: ')
#
#     # Find closest match
#     find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
#
#     if len(find_close_match) > 0:
#         close_match = find_close_match[0]
#
#         # Get index of the movie
#         index_of_the_movie = movies_by_director[movies_by_director['title'] == close_match].index[0]
#
#         # Selecting relevant features for recommendation
#         selected_features = ['genres', 'keywords', 'tagline', 'cast', 'director']
#         features = ' '.join(movies_by_director.loc[index_of_the_movie, feature] for feature in selected_features)
#
#         # Vectorize the selected features
#         tfidf_vectorizer = TfidfVectorizer()
#         tfidf_matrix = tfidf_vectorizer.fit_transform(movies_by_director[selected_features].fillna(''))
#
#         # Compute similarity scores
#         similarity_score = cosine_similarity(tfidf_matrix[index_of_the_movie], tfidf_matrix)
#
#         # Sort similar movies
#         sorted_similar_movies = sorted(enumerate(similarity_score[0]), key=lambda x: x[1], reverse=True)
#
#         print('Movies suggested for you:')
#
#         # Print recommended movies
#         for i, (index, sim_score) in enumerate(sorted_similar_movies[:30], 1):
#             title_from_index = movies_by_director.iloc[index]['title']
#             print(f'{i}. {title_from_index}')
#     else:
#         print('No similar movies found.')

# %%
print(movies_data['keywords'])
# Out:
# 0       culture clash future space war space colony so...
# 1       ocean drug abuse exotic island east india trad...
# 2              spy based on novel secret agent sequel mi6
# 3       dc comics crime fighter terrorist secret ident...
# 4       based on novel mars medallion space travel pri...
#                               ...
# 4798    united states\u2013mexico barrier legs arms pa...
# 4799
# 4800    date love at first sight narration investigati...
# 4801
# 4802                 obsession camcorder crush dream girl
# Name: keywords, Length: 4803, dtype: object

# %%
# Assuming 'movies_data' is your DataFrame containing movie data

# Get all keywords from the 'keywords' column
all_keywords = movies_data['keywords'].str.split(', ').explode().dropna()

# Convert the Series to a set to get unique keywords
unique_keywords = set(all_keywords)

# Print all unique keywords
for keyword in unique_keywords:
    print(keyword)
# Out:
# gay new york free love swinger club transsexuality
# railroad robber california delorean indian territory sports car
# crooked lawyer bail jumper mafia accountant stretch limousine manhattan
# music record rock and roll pop hip-hop fab four
# kidnapping coronation villain kingdom heir to the throne
# wormhole space travel supernatural powers spaceship alien
# corruption fortune teller money transfer money laundering pottery
# gunslinger usa dc comics hell facial scar
# alcoholism ranchers rancher rebellious youth
# robbery diamant intelligence bank robber thief
# fbi hydrogen bomb secret lab energy supply conspiracy
# asia island mercenary independent film jungle
# lovesickness sexuality cheating cynic ladykiller
# bomb sniper tv show hostage drama police
# loss of father vigilante serum marvel comic scientific experiment
# martial arts authority tournament battle fighting
# gay dancing detective confession beach
# ...

# %%
# User input for keyword
search_keyword = input('Enter a keyword to search for movies: ')

# Filter movies by whether the specified keyword is present in the 'keywords' column
matching_movies = movies_data[movies_data['keywords'].str.contains(search_keyword, case=False, na=False)]

if len(matching_movies) == 0:
    print(f'No movies found with the keyword "{search_keyword}".')
else:
    print('Movies found with the keyword "{search_keyword}":')
    # Print titles of matching movies
    for title in matching_movies['title']:
        print(title)
# Out:
# Enter a keyword to search for movies:  music
# Movies found with the keyword "{search_keyword}":
# Tangled
# Frozen
# Happy Feet Two
# Mulan
# Rio
# Enchanted
# Fantasia 2000
# Dreamgirls
# Hollywood Homicide
# Rock of Ages
# Annie
# This Is It
# The Soloist
# Pocahontas
# Muppets Most Wanted
# Burlesque
# Anastasia
# Moulin Rouge!
# Mamma Mia!
# Into the Woods
# The Boat That Rocked
# The Cotton Club
# The Muppets
# Coyote Ugly
# Across the Universe
# The Producers
# 8 Mile
# Ray
# Get Rich or Die Tryin'
# Rent
# New York Minute
# Walk Hard: The Dewey Cox Story
# Cats Don't Dance
# Mr. Holland's Opus
# Chicago
# Hannah Montana: The Movie
# Step Up 3D
# Take the Lead
# Pitch Perfect 2
# Walk the Line
# Aladdin
# Straight Outta Compton
# Taking Woodstock
# The Blues Brothers
# About a Boy
# The Magic Flute
# O Brother, Where Art Thou?
# Nothing to Lose
# Dance Flick
# Cirque du Soleil: Worlds Away
# Footloose
# The Wiz
# Beyond the Sea
# The Best Little Whorehouse in Texas
# ...
